# %%
from ai_physicist import struct_oscillation, parse_exp, eval_exp

# %%
exp_oscillation = struct_oscillation()

# %%
exp_oscillation.random_sample()
expdata = exp_oscillation.get_expdata(2, 100, 1e-8, 100)
expr = parse_exp("D[posx[1]'']/D[posx[1]]")
result = eval_exp(expr, expdata)

# %%
result.is_conserved(), result.is_zero()
# Out:
# (True, False)

# %%
result.data
# Out:
# [[nan,
#   0.0,
#   nan,
#   -2.3579201810120844,
#   -2.361030313436133,
#   -2.3579831525240706,
#   -2.35780289882946,
#   -2.354753134058775,
#   -2.3503509724769183,
#   -2.3581511791393512,
#   -2.362911316357879,
#   -2.3729117985797368,
#   -2.417027662582547,
#   -2.369080349128742,
#   -2.344857872654394,
#   -2.3565467372827844,
#   -2.3593588012948197,
#   -2.356522174068505,
#   -2.359733563154905,
#   -2.354853407422253,
#   -2.35201789936529,
#   -2.359670987010667,
#   -2.3623779976817385,
#   -2.3525282913265166,
#   -2.3520042948287925,
#   -2.362270153536775,
#   -2.357551371777046,
#   -2.353507488190937,
#   -2.3579607733896912,
#   -2.355332750284651,
#   -2.357156003595052,
#   -2.359779247637786,
#   -2.3549731851884794,
#   -2.355195632349397,
#   -2.356773710314242,
#   -2.3575869524156694,
#   -2.3587098170304093,
#   -2.354587524769426,
#   -2.3561212252920987,
#   -2.3581009225124046,
#   -2.3558649492360617,
#   -2.35755745574113,
# ...
