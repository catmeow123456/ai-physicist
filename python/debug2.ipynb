# %%
import os
from main import Theorist
from interface import MeasureType
from dataplot import plot_datastruct, plot_data
os.chdir('/home/fyl/ai-physicist')

# %%
theorist: Theorist = Theorist.read_from_file('data/knowledge.txt', 'data/memory.json')

# %%
exp = theorist.general.fetch_expstruct('oscillation')

# %%
exp.random_settings()

# %%
DS = theorist.specific['oscillation'].pick_relevant_exprs()
print(DS)
# Out:
# [DataStruct] data:posx[1],C_13[1, 0],C_10[2, 1],C_04[0, 1],C_07[1, 2],C_06[1, 2],C_16[2],C_03[1, 0],C_09[2, 1],posl[2],C_01[1, 0],t[0],C_08[1, 0],C_11[2, 1],C_14[1, 0, 2],C_12[2, 1, 0],C_02[0, 1],posr[2],C_15[1],.

# %%
expdata = theorist.general.eval("posr[2] + D[posr[2]]/D[C_04[0, 1]] * C_04[0, 1]", exp)
plot_data('data', expdata)
# Out:
# data: const data, mean = 11.00854717414954, std = 4.5990336108873133e-05

# %%
expdata = theorist.general.eval("D[C_16[2]*posx[1]]/D[C_03[1,0] / C_15[1]]", exp)
plot_data('data', expdata)
# Out:
# data: const data, mean = -0.07888337361132529, std = 3.9874729851642364e-05

# %%
expdata = theorist.general.eval('D[(C_04[0, 1] * posr[2])]/D[(C_04[0, 1] * C_08[1, 0])]', exp)
plot_data('data', expdata)
# Out:
# data: const data, mean = -23.450573312231253, std = 6.914727240857236e-05

# %%
expdata = theorist.general.eval('D[(C_16[2] * posr[2])]/D[(C_11[2, 1] * posx[1])]', exp)
plot_data('data', expdata)
# Out:
# data: const data, mean = -0.4175341843139059, std = 0.00016341974436515747

# %%
expdata = theorist.general.eval('D[(C_04[0, 1] * posl[2])]/D[C_04[0, 1]]', exp)
plot_data('data', expdata)
# Out:
# data: const data, mean = 0.8387525712052625, std = 5.160286623434995e-12
